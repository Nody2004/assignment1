# %% [markdown]
# <a href="https://colab.research.google.com/github/Nody2004/assignment1/blob/main/Assignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Discuss string slicing and provide examples.

''' A string in python can be sliced for gettin a prot of the strings.
Example of string slicing:- '''
string = "Hello World!"
sliced_string = string[0:5]
print(sliced_string)
'''This will slice the above string and will print Hello only.

Another example of string slicing:-'''
name = "Priyanshu"
sliced_name = name[:-1]
print(sliced_name) #This will only print 'Priyansh' as letter at -1 index is excluded




# 2. Explain the key features of lists in python.

""" 1. List are containers to store a set of values of any data types.
    2. It is mutuable, i.e you can update list once created.
    3. You can store anything in lists.
    4. List is an ordered collection of any data type."""




# 3. Describe how to access, modify, and delete elements in a list with examples.

""" Consider the following list:- """
list_1 = [1, 8, 9, 3, 5, "pw", 43]

""" To access list we can refer to there index value
    Example:- we want to access 'pw', we will just refer to it's index value """
access = list_1[5]
print(access)# This will return 'pw'
""" We can also access 'pw' using negative indexing """
negative = list_1[-2]
pring(negative)

"""To modify the above list, we will just refer the index of the element and assign new element to that index
   Example:- We will modify 'pw' with 'physics_wallah' """
list_1[-2] = "physics_wallah"
print(list_1)

""" To delete an element from the list we will use remove() method
    Example:- we want to remove 9 from the list """
list_1.remove(9)
print(list_1)#This will remove 1 from the list and print remaning elements



# 4. Compare and contrast tuples and lists with examples.

""" 1. Lists are mutable, on the other hand tuples are immutable
    2.use case:-
     Lists are used to store data which can be modified after creation.
     example:- To do list activities.


     Tuples are used to store data which is not editable after creation.
     example:- aadhar card no. , employee id etc. """

L1 = [0,12,2,3,4,5,6,7]
L1[-1] = 100
print(L1)# Example of mutability of list.


T1 = (0,12,2,3,4,5,6,7)
T1[-1] = 100
print(T1)#This will throw error:- 'tuple' object does not support item assignment.



# 5. Describe the key features of sets and provide examples of their use.

"""Sets are unordered collection of unique elements.
   Sets cam be mutable.
   The order doesn't matter, and duplicate entries are not allowed. """

set1 = {"red", "yellow", "green", "red", "blue", "orange","green"}
print(set1)#this will only print unique elements and remove repetative elements.


# 6. Discuss the use cases of tuples and sets in Python programming.

""" TUPLES :-
    1.Elements cannot be modified after creation.
    2.Elements have a specific order.
    3.Duplicates allowed.
    4.Representing data that should not change.


    SETS :-
    1.Elements can be modified after creation.
    2.Elements have no specific order.
    3.Duplicates not allowed.
    4.Eliminating duplicates, Checking for membership, Mathematical operations (union, intersection) """


# 7. Describe how to add, modify, and delete items in a dictionary with examples.

""" Consider the following dictionary :- """
dict = {"name":"Priyanshu","From":"India","Mobile_No.":123456789}

#To add something in existing dictionary, update() method is used.
dict.update({"religion":"hindu"})#this will update the dictionary with supplied key-value pair.
print(dict)

#To modify element in existing dictionary, we will first access the key and then assign new value to it.
#example:- We want to change Mobile_No.
dict["Mobile_No."] = 88888888888 #Mobile_No. is replaced with new number.
print(dict)

#To delete elements from existing dictionary, we will use pop() method.
#example:- remove "from":"India"
dict.pop("From")
print(dict)




# 8. Discuss the importance of dictionary keys being immutable and provide examples.

""" Consistency: For a key to be reliably retrievable, it must remain constant. If keys could change, it would break the fundamental property of dictionaries, which is that a given key should always return the same value.

   Performance: The performance of dictionaries relies on the efficiency of hashing. If keys were mutable, the dictionary would have to handle the complexities of tracking changes to keys, which would slow down operations like insertion, deletion, and lookup.
    """
