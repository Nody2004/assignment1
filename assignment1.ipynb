# %% [markdown]
# <a href="https://colab.research.google.com/github/Nody2004/assignment1/blob/main/assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# question 1:- Explain the key features of python that make it a popular choice for programming.

""" Python is popular choice for programming because :-
  1. Widely used in the industry.
  2. A lot of libraries are available in python.
  3. It is very easy to learn and read python.
  4. A large active community."""



# question 2:- Describe the role of predefined keywords in python and provide examples of how they are use in a program.

'''Predefined keyword are the words that hold a specific meaning and specific purpose.

   * print():- print keyword is a word that is used to print something in python
     example- print("Hello world")
     This will print Hello world


   *type():- type keyword is used to get data type of an entity
    example- type(32)
    This will return int data type'''



# question 3:- Compare and contrast mutable and immutable objects in python with example.


''' Objects/container whose state or value can be changed after they are created are known as mutable objects
   List data structure is a type of mutable object
   example:- Lets create a list
   L1 = [1,2,3,4,5,6,'python']
   Now we can change or edit this list. First we need to access the element using index no.

   L1[7], This will return python
   L1[7] = anaconda, this will replace python with anaconda.




   Objects/conatiner whose state or value cannot be changed after they are created are known as immutable objects
     tuple is an example on immutable object.
     T1 = {1,2,3,4,5,'python'}
     once a tuple is created we cannot edit it. '''





# question 4:-  Discuss the different types of operators in python and provide examples of how they are used.


'''Operators are special symbols or keywords that are used to carry out specific actions on numbers or variables in Python expressions
   Types of operators are :-
   1. Arithmetic operators(+,-,*,/)
     These operators are used to perform arithmetic operations on numbers
     example:-
     a = 5
     b = 6
     a + b (this will return 11.)
     a - b (this will return -1.)



   2. Logical operators(and,or,not)
      These operators are used to perform logical operatios on numbers or variables
      example:-
      a = true
      b = false
      a and b (result will be false)
      a or b  (result will be true)




    3. comparison operators(==,!=,>,<)
       These operators are used to do comparison between different numbers or variables.
       example:-
       a = 5
       b = 10
       a == b (this will result as false)
       a != b (this will result as true)
       a > b (this will result as false)
       a < b (this will result as true)




     4. Assignment operators (=, +=, -=, *=, /=)
        These operators are used to assign values to the variables.
        example:-
        a = 5 (Here a is assigned with 5)
        a += 6 (In this, first a which is 5 will be added with 6. Then the final value will be stored in a)
        a *= 2 (a will be first multiplyed by 2, then the result will be stored in a)

      '''






# question 5:- Explain the concept of type casting in python with examples.


'''Type casting is a method of changing one data type to another data type in python.
   example:-
   a = 36
   Currently has an integer value stored in it, if we want to change the value of a from int to string we will perform below operation
   type(a) (This will return as int type)
   str(a) (this will change the type of a from integer to string. Now if we perfrom type(a) it will result as str.)

   Similarly we can change it into various data types, example:-  float(), list(), tuple(), dict(), etc. '''





# question 6:- How do conditional statements work in python? Illustrate with examples.


'''Conditionals in Python are used to execute code based on the evaluation of one or more conditions.
  Python supports conditional statements such as if, elif (else if), and else to control the flow of execution.
  example:- Lets check if the user is eligible to drive a vehicle.

   '''
name = input("Please enter your name")
age = int(input("please enter your current age"))

if(age >= 18):
      print(f"congratulations {name} you are eligible to drive a vehicle")
else:
    print(f"Sorry {name} you are not eligible to drive vehicle")





#questiom 7:- Describe the different types of loops in python and their use cases with examples.

'''In Python, loops are employed to repeat a sequence of actions or code until a specific condition is fulfilled.
Python offers two primary types of loops: for loops and while loops.
“for” loops are used for iterating over a sequence of elements, while “while” loops are used for executing code until a specified condition becomes False '''

# while loop example  for printing hello multiple times
i = 0
while (i<5):
    print("hello")
    i = i+1



# for loop example to print multiplication table of 5.
a = 5
for i in range(1,11):
    print(f"{a} X {i} = {a*i}")
